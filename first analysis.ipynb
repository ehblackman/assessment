# %% [markdown]
# # My Jupyter Notebook on IBM Watson Studio

# %% [markdown]
# By **Edward Blackman**
#
# Postgraduate researcher at the University of Durham, Earth Sciences Department.

# %% [markdown]
# I am interested in using data science to proccess large volumes of geological data for my research on subsurface hydrogen. My aim is to apply analytical models which go beyond simple regression such as Bayesian inference.

# %% [markdown]
# This piece of code plots the relationship between hydrogen and nitrogen.

# %%
import os, types
import pandas as pd
from botocore.client import Config
import ibm_boto3

def __iter__(self): return 0

# @hidden_cell
# The following code accesses a file in your IBM Cloud Object Storage. It includes your credentials.
# You might want to remove those credentials before you share the notebook.
client_8620ae9b7b25484a938faaa5f9bf776e = ibm_boto3.client(service_name='s3',
    ibm_api_key_id='QmRW2Nh63196B2oFOuu_KvrquPRT0c72ehPScZgoHNBP',
    ibm_auth_endpoint="https://iam.cloud.ibm.com/oidc/token",
    config=Config(signature_version='oauth'),
    endpoint_url='https://s3.private.us.cloud-object-storage.appdomain.cloud')

body = client_8620ae9b7b25484a938faaa5f9bf776e.get_object(Bucket='firstproject-donotdelete-pr-lctsewqfhiws35',Key='H2 +5% wells.csv')['Body']
# add missing __iter__ method, so pandas accepts body as file-like object
if not hasattr(body, "__iter__"): body.__iter__ = types.MethodType( __iter__, body )


df_data_1 = pd.read_csv(body)
df_data_1.plot(x ='H2 Air Free', y='Gas Dryness Ratio', kind = 'scatter')
# Out:
# <AxesSubplot:xlabel='H2 Air Free', ylabel='Gas Dryness Ratio'>

# %% [markdown]
# To learn more about subsurface hydrogen visit the following links:
# - __[Durham Energy Institute](https://www.durham.ac.uk/research/institutes-and-centres/durham-energy-institute/)__
# - __[Gold hydrogen definition](https://www.earth.ox.ac.uk/2021/09/gold-hydrogen-oxford-earth-sciences-in-the-times/)__
#
# ![Ascent-Hydrogen-Fund-Signs-New-Deal-with-Spains-Helios-Aragon-1.jpg](attachment:Ascent-Hydrogen-Fund-Signs-New-Deal-with-Spains-Helios-Aragon-1.jpg)
